# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # ***Reading the Data set***

# %%
mushrooms= pd.read_csv('/content/mushrooms.csv')
mushrooms.head(50)
# Out:
#    class cap-shape cap-surface  ... spore-print-color population habitat
# 0      p         x           s  ...                 k          s       u
# 1      e         x           s  ...                 n          n       g
# 2      e         b           s  ...                 n          n       m
# 3      p         x           y  ...                 k          s       u
# 4      e         x           s  ...                 n          a       g
# 5      e         x           y  ...                 k          n       g
# 6      e         b           s  ...                 k          n       m
# 7      e         b           y  ...                 n          s       m
# 8      p         x           y  ...                 k          v       g
# 9      e         b           s  ...                 k          s       m
# 10     e         x           y  ...                 n          n       g
# 11     e         x           y  ...                 k          s       m
# ...

# %%
mushrooms.shape
# Out:
# (8124, 23)

# %%
mushrooms.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
mushrooms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int64
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
mushrooms.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# # *Data Visualization*

# %%
cl={'p':1,'e':2}
mushrooms['class']=mushrooms['class'].map(cl)
mushrooms.head(10)
# Out:
#    class cap-shape cap-surface  ... spore-print-color population habitat
# 0    NaN         x           s  ...                 k          s       u
# 1    NaN         x           s  ...                 n          n       g
# 2    NaN         b           s  ...                 n          n       m
# 3    NaN         x           y  ...                 k          s       u
# 4    NaN         x           s  ...                 n          a       g
# 5    NaN         x           y  ...                 k          n       g
# 6    NaN         b           s  ...                 k          n       m
# 7    NaN         b           y  ...                 n          s       m
# 8    NaN         x           y  ...                 k          v       g
# 9    NaN         b           s  ...                 k          s       m
#
# [10 rows x 23 columns]

# %%
sns.factorplot("habitat","class",data=mushrooms).set(ylim=(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot( "cap-shape","class", data=mushrooms,order=['x','f','k','b','s','c'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.factorplot("cap-color", "class", data=mushrooms).set(ylim=(1, 3))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot( "population","class", data=mushrooms)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot( "cap-surface","class", data=mushrooms,order=['y','s','f','g'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot( "stalk-color-below-ring","class", data=mushrooms)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot( "odor","class", data=mushrooms,order=['n','f','s','y','l','a','p','c','m'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.factorplot("stalk-root", "class", data=mushrooms).set(ylim=(1, 2))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,18))
sns.heatmap(mushrooms.corr(), annot=True, linewidths=0.7, fmt='.4f')

# %%
mushrooms.corr()
# Out:
#                              class  cap-shape  ...  population   habitat
# class                     1.000000   0.034451  ...    0.446307 -0.078160
# cap-shape                 0.034451   1.000000  ...    0.094009  0.216553
# cap-surface               0.159155  -0.058042  ...    0.092017 -0.135708
# cap-color                -0.011735   0.029639  ...    0.195487  0.155114
# bruises                   0.501530  -0.057287  ...    0.071736  0.010061
# odor                     -0.323569   0.017134  ...   -0.011620  0.158634
# gill-attachment           0.129200   0.126426  ...    0.193065  0.146291
# gill-spacing              0.348387  -0.005866  ...    0.433383 -0.115027
# gill-size                -0.540024   0.083962  ...   -0.396480  0.118962
# gill-color                0.334999  -0.016882  ...    0.375137  0.075706
# stalk-shape              -0.102019   0.116854  ...    0.258171  0.302504
# stalk-root                0.248390   0.190482  ...    0.463674  0.354307
# ...

# %% [markdown]
# # *Data Preprocessing*

# %%
#encoding
mushrooms['cap-shape'].value_counts()
Cpshp = {'x': 1, 'f':2 , 'k' : 3,'b' : 4, 's' : 5,'c':6}
mushrooms['cap-shape']= mushrooms['cap-shape'].map(Cpshp)
mushrooms.head(10)
# Out:
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64

# %%
mushrooms['cap-surface'].value_counts()
cfsfc={'y':1,'s':2, 'f':3,'g':4}
mushrooms['cap-surface']=mushrooms['cap-surface'].map(cfsfc)
mushrooms.head(10)
# Out:
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64

# %%
mushrooms['cap-color'].value_counts()
cpcolor={'n': 1,'g':2,'e':3,'y':4,'w':5,'b':6,'p':7,'c':8,'r':9,'u':10}
mushrooms['cap-color']=mushrooms['cap-color'].map(cpcolor)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population habitat
# 0      1          1            2  ...                  k          s       u
# 1      2          1            2  ...                  n          n       g
# 2      2          4            2  ...                  n          n       m
# 3      1          1            1  ...                  k          s       u
# 4      2          1            2  ...                  n          a       g
# 5      2          1            1  ...                  k          n       g
# 6      2          4            2  ...                  k          n       m
# 7      2          4            1  ...                  n          s       m
# 8      1          1            1  ...                  k          v       g
# 9      2          4            2  ...                  k          s       m
#
# [10 rows x 23 columns]

# %%
mushrooms['odor'].value_counts()
odor={'n':1,'f':2,'y':3,'s':4,'l':5,'a':6,'p':7,'c':8,'m':9}
mushrooms['odor']=mushrooms['odor'].map(odor)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['gill-attachment'].value_counts()
gat={'f':1,'a':2}
mushrooms['gill-attachment']=mushrooms['gill-attachment'].map(gat)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['stalk-shape'].value_counts()
Sshape={'t':1,'e':2}
mushrooms['stalk-shape']=mushrooms['stalk-shape'].map(Sshape)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['stalk-root'].value_counts()
sroot={'b':1,'?':2,'e':3,'c':4,'r':5}
mushrooms['stalk-root']=mushrooms['stalk-root'].map(sroot)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['stalk-color-below-ring'].value_counts()
Scolorbelowring={'w':1,'p':2,'g':3,'n':4,'b':5,'o':6,'e':7,'c':8,'y':9}
mushrooms['stalk-color-below-ring']=mushrooms['stalk-color-below-ring'].map(Scolorbelowring)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['stalk-color-above-ring'].value_counts()
ScolorAbovering={'w':1,'p':2,'g':3,'n':4,'b':5,'o':6,'e':7,'c':8,'y':9}
mushrooms['stalk-color-above-ring']=mushrooms['stalk-color-above-ring'].map(ScolorAbovering)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['stalk-surface-above-ring'].value_counts()
StalkSurfaceAbovering={'s':1,'k':2,'f':3,'y':4}
mushrooms['stalk-surface-above-ring']=mushrooms['stalk-surface-above-ring'].map(StalkSurfaceAbovering)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['stalk-surface-below-ring'].value_counts()
stalksurfacebelowring={'s':1,'k':2,'f':3,'y':4}
mushrooms['stalk-surface-below-ring']=mushrooms['stalk-surface-below-ring'].map(stalksurfacebelowring)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['veil-color'].value_counts()
vcolor={'w':1,'o':2,'n':3,'y':4}
mushrooms['veil-color'] =mushrooms['veil-color'].map(vcolor)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['ring-number'].value_counts()
ringnumber={'o':1,'t':2,'n':3}
mushrooms['ring-number']=mushrooms['ring-number'].map(ringnumber)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['ring-type'].value_counts()
ringtype={'p':1,'e':2,'l':3,'f':4,'n':5}
mushrooms['ring-type']=mushrooms['ring-type'].map(ringtype)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  k          s        u
# 1      2          1            2  ...                  n          n        g
# 2      2          4            2  ...                  n          n        m
# 3      1          1            1  ...                  k          s        u
# 4      2          1            2  ...                  n          a        g
# 5      2          1            1  ...                  k          n        g
# 6      2          4            2  ...                  k          n        m
# 7      2          4            1  ...                  n          s        m
# 8      1          1            1  ...                  k          v        g
# 9      2          4            2  ...                  k          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['spore-print-color'].value_counts()
sporeprintcolor={'w':1,'n':2,'k':3,'h':4,'r':5,'o':6,'y':7,'b':8,'u':9}
mushrooms['spore-print-color']=mushrooms['spore-print-color'].map(sporeprintcolor)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  3          s        u
# 1      2          1            2  ...                  2          n        g
# 2      2          4            2  ...                  2          n        m
# 3      1          1            1  ...                  3          s        u
# 4      2          1            2  ...                  2          a        g
# 5      2          1            1  ...                  3          n        g
# 6      2          4            2  ...                  3          n        m
# 7      2          4            1  ...                  2          s        m
# 8      1          1            1  ...                  3          v        g
# 9      2          4            2  ...                  3          s        m
#
# [10 rows x 23 columns]

# %%
mushrooms['population'].value_counts()
population={'v':1,'y':2,'s':3,'n':4,'a':5,'c':6}
mushrooms['population']=mushrooms['population'].map(population)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  3          3        u
# 1      2          1            2  ...                  2          4        g
# 2      2          4            2  ...                  2          4        m
# 3      1          1            1  ...                  3          3        u
# 4      2          1            2  ...                  2          5        g
# 5      2          1            1  ...                  3          4        g
# 6      2          4            2  ...                  3          4        m
# 7      2          4            1  ...                  2          3        m
# 8      1          1            1  ...                  3          1        g
# 9      2          4            2  ...                  3          3        m
#
# [10 rows x 23 columns]

# %%
mushrooms['habitat'].value_counts()
habitat={'d':1,'g':2,'p':3,'l':4,'u':5,'m':6,'w':7}
mushrooms['habitat']=mushrooms['habitat'].map(habitat)	
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  3          3        5
# 1      2          1            2  ...                  2          4        2
# 2      2          4            2  ...                  2          4        6
# 3      1          1            1  ...                  3          3        5
# 4      2          1            2  ...                  2          5        2
# 5      2          1            1  ...                  3          4        2
# 6      2          4            2  ...                  3          4        6
# 7      2          4            1  ...                  2          3        6
# 8      1          1            1  ...                  3          1        2
# 9      2          4            2  ...                  3          3        6
#
# [10 rows x 23 columns]

# %%
mushrooms['gill-spacing'].value_counts()
gillspacing={'c':1,'w':2}
mushrooms['gill-spacing']=mushrooms['gill-spacing'].map(gillspacing)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  3          3        5
# 1      2          1            2  ...                  2          4        2
# 2      2          4            2  ...                  2          4        6
# 3      1          1            1  ...                  3          3        5
# 4      2          1            2  ...                  2          5        2
# 5      2          1            1  ...                  3          4        2
# 6      2          4            2  ...                  3          4        6
# 7      2          4            1  ...                  2          3        6
# 8      1          1            1  ...                  3          1        2
# 9      2          4            2  ...                  3          3        6
#
# [10 rows x 23 columns]

# %%
mushrooms['gill-size'].value_counts()
gillsize={'b':1,'n':2}
mushrooms['gill-size']=mushrooms['gill-size'].map(gillsize)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  3          3        5
# 1      2          1            2  ...                  2          4        2
# 2      2          4            2  ...                  2          4        6
# 3      1          1            1  ...                  3          3        5
# 4      2          1            2  ...                  2          5        2
# 5      2          1            1  ...                  3          4        2
# 6      2          4            2  ...                  3          4        6
# 7      2          4            1  ...                  2          3        6
# 8      1          1            1  ...                  3          1        2
# 9      2          4            2  ...                  3          3        6
#
# [10 rows x 23 columns]

# %%
mushrooms['bruises'].value_counts()
# Out:
# f    4748
# t    3376
# Name: bruises, dtype: int64

# %%
mushrooms['gill-color'].value_counts()
gillcolor={'b':1,'p':2,'w':3,'n':4,'g':5,'h':6,'u':7,'k':8,'e':9,'y':10,'o':11,'r':12}
mushrooms['gill-color']=mushrooms['gill-color'].map(gillcolor)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color population  habitat
# 0      1          1            2  ...                  3          3        5
# 1      2          1            2  ...                  2          4        2
# 2      2          4            2  ...                  2          4        6
# 3      1          1            1  ...                  3          3        5
# 4      2          1            2  ...                  2          5        2
# 5      2          1            1  ...                  3          4        2
# 6      2          4            2  ...                  3          4        6
# 7      2          4            1  ...                  2          3        6
# 8      1          1            1  ...                  3          1        2
# 9      2          4            2  ...                  3          3        6
#
# [10 rows x 23 columns]

# %%
br={'f': 1,'t': 2}
mushrooms['bruises']= mushrooms.bruises.map(br)
mushrooms.head(10)
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color  population  habitat
# 0      1          1            2  ...                  3           3        5
# 1      2          1            2  ...                  2           4        2
# 2      2          4            2  ...                  2           4        6
# 3      1          1            1  ...                  3           3        5
# 4      2          1            2  ...                  2           5        2
# 5      2          1            1  ...                  3           4        2
# 6      2          4            2  ...                  3           4        6
# 7      2          4            1  ...                  2           3        6
# 8      1          1            1  ...                  3           1        2
# 9      2          4            2  ...                  3           3        6
#
# [10 rows x 23 columns]

# %%
mushrooms=mushrooms.drop(['veil-type'],axis=1)
mushrooms.head()
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color  population  habitat
# 0      1          1            2  ...                  3           3        5
# 1      2          1            2  ...                  2           4        2
# 2      2          4            2  ...                  2           4        6
# 3      1          1            1  ...                  3           3        5
# 4      2          1            2  ...                  2           5        2
#
# [5 rows x 22 columns]

# %% [markdown]
# # *Build the Model*

# %%
X_train=mushrooms.drop("class",axis=1)
Y_train=mushrooms["class"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X_train,Y_train, test_size=0.3)

# %% [markdown]
# # *Logictic Regression*

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr = lr.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,precision_score,recall_score,f1_score
act = accuracy_score(Y_train,lr.predict(X_train))   
print('Training Accuracy is: ',(act*100))
p = precision_score(Y_train,lr.predict(X_train))
print('Training Precision is: ',(p*100))
r = recall_score(Y_train,lr.predict(X_train))
print('Training Recall is: ',(r*100))
f = f1_score(Y_train,lr.predict(X_train))
print('Training F1 Score is: ',(f*100))
# Out:
# Training Accuracy is:  98.59303552585297
# Training Precision is:  98.65503453289712
# Training Recall is:  98.44033369604642
# Training F1 Score is:  98.54756717501816

# %%
act = accuracy_score(Y_test,lr.predict(X_test))
print('Test Accuracy is: ',(act*100))
p = precision_score(Y_test,lr.predict(X_test))
print('Test Precision is: ',(p*100))
r = recall_score(Y_test,lr.predict(X_test))
print('Test Recall is: ',(r*100))
f = f1_score(Y_test,lr.predict(X_test))
print('Test F1 Score is: ',(f*100))
# Out:
# Test Accuracy is:  98.11320754716981
# Test Precision is:  98.18181818181819
# Test Recall is:  97.84296807592753
# Test F1 Score is:  98.01210025929127

# %% [markdown]
# # *Random Forest Classifier*

# %%
from sklearn.ensemble import RandomForestClassifier



rf = RandomForestClassifier(criterion = "gini", 
                                       min_samples_leaf = 3, 
                                       min_samples_split = 10,   
                                       n_estimators=100, 
                                       max_features=0.5, 
                                       oob_score=True, 
                                       random_state=1, 
                                       n_jobs=-1)
rf = rf.fit(X_train,Y_train)

# %%
act = accuracy_score(Y_train,rf.predict(X_train))
print('Training Accuracy is: ',(act*100))
p = precision_score(Y_train,rf.predict(X_train))
print('Training Precision is: ',(p*100))
r = recall_score(Y_train,rf.predict(X_train))
print('Training Recall is: ',(r*100))
f = f1_score(Y_train,rf.predict(X_train))
print('Training F1 Score is: ',(f*100))
# Out:
# Training Accuracy is:  100.0
# Training Precision is:  100.0
# Training Recall is:  100.0
# Training F1 Score is:  100.0

# %%
act = accuracy_score(Y_test,rf.predict(X_test))
print('Test Accuracy is: ',(act*100))
p = precision_score(Y_test,rf.predict(X_test))
print('Test Precision is: ',(p*100))
r = recall_score(Y_test,rf.predict(X_test))
print('Test Recall is: ',(r*100))
f = f1_score(Y_test,rf.predict(X_test))
print('Test F1 Score is: ',(f*100))
# Out:
# Test Accuracy is:  100.0
# Test Precision is:  100.0
# Test Recall is:  100.0
# Test F1 Score is:  100.0

# %% [markdown]
# # *Decision Tree classifier*

# %%
from sklearn.tree import DecisionTreeClassifier


dt = DecisionTreeClassifier()
dt=dt.fit(X_train, Y_train)

# %%
act = accuracy_score(Y_train,dt.predict(X_train))
print('Training Accuracy is: ',(act*100))
p = precision_score(Y_train,dt.predict(X_train))
print('Training Precision is: ',(p*100))
r = recall_score(Y_train,dt.predict(X_train))
print('Training Recall is: ',(r*100))
f = f1_score(Y_train,dt.predict(X_train))
print('Training F1 Score is: ',(f*100))
# Out:
# Training Accuracy is:  100.0
# Training Precision is:  100.0
# Training Recall is:  100.0
# Training F1 Score is:  100.0

# %%
act = accuracy_score(Y_test,dt.predict(X_test))
print('Test Accuracy is: ',(act*100))
p = precision_score(Y_test,dt.predict(X_test))
print('Test Precision is: ',(p*100))
r = recall_score(Y_test,dt.predict(X_test))
print('Test Recall is: ',(r*100))
f = f1_score(Y_test,dt.predict(X_test))
print('Test F1 Score is: ',(f*100))
# Out:
# Test Accuracy is:  100.0
# Test Precision is:  100.0
# Test Recall is:  100.0
# Test F1 Score is:  100.0
